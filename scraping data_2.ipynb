# %%
import requests
import os
import json
from datetime import datetime, timezone # Ensure timezone is imported
from urllib.parse import urljoin, urlencode

# ========== CONFIGURATION ==========

DISCOURSE_BASE_URL = "https://discourse.onlinedegree.iitm.ac.in/"
CATEGORY_SLUG = "courses/tds-kb"
CATEGORY_ID = 34
START_DATE = "2025-01-01" # Inclusive
END_DATE = "2025-04-15"   # Inclusive

RAW_COOKIE_STRING = """
_t=1SOCfo%2Fj2T%2FtX92BG4b094n0OnjvWRFYk9oxJBwlIjhufEm9JalIzgN1yMijQjfBAQBdtVE8wCOQ9weUeuNWIubdSa8UvP6Cv9pB9GI%2FGBHkg8SaczEPW6%2FWktpJ3Aro6mGM3%2BvEFvaAkvPbF5EkDO0cs10BNHdRaiF83UavRy2GeEuipdQBbYcQeeOldysypZ%2BpKrv69A7pHzaRqWR7scv6ItjOxFDu%2Fdu7bsDeSzUU1rbMkVqn8xQzB%2FZUWfqyZWqmfBbrQXadamDfOwKVHfxQhQ8Jwoda%2F52ADp5b68sCUw6OIPD2%2FXm%2FLVQ%3D--IvQe%2Fc78ozph6N1%2B--wOTHvj22ffFZ094E%2Fm6vxw%3D%3D""" # Replace with your actual cookie string

OUTPUT_DIR = "discourse_json"
POST_ID_BATCH_SIZE = 50
MAX_CONSECUTIVE_PAGES_WITHOUT_NEW_TOPICS = 5 # New configuration for breaking loop

# ====================================

def parse_cookie_string(raw_cookie_string):
    """Parses a raw cookie string into a dictionary."""
    cookies = {}
    if not raw_cookie_string.strip():
        print("Warning: RAW_COOKIE_STRING is empty. Requests might fail if authentication is needed.")
        return cookies
    for cookie_part in raw_cookie_string.strip().split(";"):
        if "=" in cookie_part:
            key, value = cookie_part.strip().split("=", 1)
            cookies[key] = value
    return cookies


def get_topic_ids(base_url, category_slug, category_id, start_date_str, end_date_str, cookies):
    """Fetches topic IDs from a specific category within a date range."""
    url = urljoin(base_url, f"c/{category_slug}/{category_id}.json")
    topic_ids = []
    page = 0

    start_dt_naive = datetime.fromisoformat(start_date_str + "T00:00:00")
    start_dt = start_dt_naive.replace(tzinfo=timezone.utc)
    end_dt_naive = datetime.fromisoformat(end_date_str + "T23:59:59.999999")
    end_dt = end_dt_naive.replace(tzinfo=timezone.utc)

    print(f"Fetching topic IDs from category between {start_dt} and {end_dt}...")

    # Variables for the new loop break condition
    consecutive_pages_with_no_new_unique_topics = 0
    last_known_unique_topic_count = 0

    while True:
        paginated_url = f"{url}?page={page}"
        try:
            response = requests.get(paginated_url, cookies=cookies, timeout=30)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Failed to fetch page {page}: {e}")
            break

        try:
            data = response.json()
        except json.JSONDecodeError:
            print(f"Failed to decode JSON from page {page}. Content: {response.text[:200]}...")
            break

        topics_on_page = data.get("topic_list", {}).get("topics", [])

        if not topics_on_page:
            print(f"No more topics found on page {page} (API returned empty list).")
            break # Primary stop condition: API says no more topics on this page

        # Store current number of unique topics before processing this page
        # This helps check if *this specific page fetch* added anything new
        count_before_processing_page = len(set(topic_ids))

        for topic in topics_on_page:
            created_at_str = topic.get("created_at")
            if created_at_str:
                try:
                    created_date = datetime.fromisoformat(created_at_str.replace("Z", "+00:00"))
                except ValueError:
                    print(f"Warning: Could not parse date '{created_at_str}' for topic ID {topic.get('id')}")
                    continue

                if start_dt <= created_date <= end_dt:
                    topic_ids.append(topic["id"]) # Add ID, will be deduped later for count

        current_unique_topic_count = len(set(topic_ids))

        if topics_on_page and current_unique_topic_count == count_before_processing_page :
            # This means the current page had topics, but none of them were new *and* within the date range,
            # or all topics fetched from this page were duplicates of ones already in topic_ids from *previous pages*.
            # For the staleness check, we care if the overall unique set isn't growing.
             pass # Handled by the check below using last_known_unique_topic_count

        # Staleness check: Has the *total* number of unique topics found stopped growing?
        if current_unique_topic_count == last_known_unique_topic_count and topics_on_page:
            # topics_on_page is checked to ensure we don't increment if an empty page was returned (which is a valid end)
            consecutive_pages_with_no_new_unique_topics += 1
            print(f"Page {page} did not yield any new unique topics. Consecutive stale pages: {consecutive_pages_with_no_new_unique_topics}.")
        else:
            consecutive_pages_with_no_new_unique_topics = 0 # Reset if new unique topics were found

        last_known_unique_topic_count = current_unique_topic_count

        if consecutive_pages_with_no_new_unique_topics >= MAX_CONSECUTIVE_PAGES_WITHOUT_NEW_TOPICS:
            print(f"No new unique topics found for {MAX_CONSECUTIVE_PAGES_WITHOUT_NEW_TOPICS} consecutive pages. Assuming end of relevant category listing.")
            break

        # Original secondary stop condition (heuristic)
        more_topics_url = data.get("topic_list", {}).get("more_topics_url")
        if not more_topics_url:
            # This typically means it's the last page.
            # The condition `len(topics_on_page) < 30` was a heuristic for when more_topics_url might be missing
            # but the page wasn't full. If more_topics_url is definitively gone, it's a strong signal.
            print(f"No 'more_topics_url' indicated on page {page}. Assuming this is the last page of topics.")
            break

        print(f"Fetched page {page}, {len(topics_on_page)} topics on page. Total unique topics found so far: {current_unique_topic_count}. Continuing...")
        page += 1


    final_unique_topic_ids = list(set(topic_ids)) # Deduplicate
    print(f"Total unique topics found in timeframe: {len(final_unique_topic_ids)}")
    return final_unique_topic_ids


def get_full_topic_json(base_url, topic_id, cookies):
    """Fetches the full topic JSON, including all posts by handling pagination."""
    initial_topic_url = urljoin(base_url, f"t/{topic_id}.json")
    print(f"Fetching initial data for topic {topic_id} from {initial_topic_url}")

    try:
        response = requests.get(initial_topic_url, cookies=cookies, timeout=30)
        response.raise_for_status()
        topic_data = response.json()
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch initial topic data for {topic_id}: {e}")
        return None
    except json.JSONDecodeError:
        print(f"Failed to decode initial JSON for topic {topic_id}. Content: {response.text[:200]}...")
        return None

    post_stream = topic_data.get("post_stream")
    if not post_stream or "stream" not in post_stream or "posts" not in post_stream:
        print(f"Error: 'post_stream' not found or incomplete in topic {topic_id}. Skipping post fetching.")
        return topic_data

    all_post_ids_in_stream = post_stream.get("stream", [])
    loaded_post_ids = {post["id"] for post in post_stream.get("posts", [])}

    all_post_ids_in_stream = [pid for pid in all_post_ids_in_stream if pid is not None]

    missing_post_ids = [pid for pid in all_post_ids_in_stream if pid not in loaded_post_ids]

    print(f"Topic {topic_id}: Total posts in stream: {len(all_post_ids_in_stream)}, Initially loaded: {len(loaded_post_ids)}, Missing: {len(missing_post_ids)}")

    if not missing_post_ids:
        print(f"All posts for topic {topic_id} already loaded in initial fetch.")
        return topic_data

    fetched_additional_posts = []
    for i in range(0, len(missing_post_ids), POST_ID_BATCH_SIZE):
        batch_ids = missing_post_ids[i:i + POST_ID_BATCH_SIZE]

        query_params = [("post_ids[]", pid) for pid in batch_ids]
        posts_url = urljoin(base_url, f"t/{topic_id}/posts.json")

        print(f"Fetching batch of {len(batch_ids)} posts for topic {topic_id} (IDs: {batch_ids[0]}...{batch_ids[-1]})")

        try:
            batch_response = requests.get(posts_url, params=query_params, cookies=cookies, timeout=60)
            batch_response.raise_for_status()
            batch_data = batch_response.json()

            if isinstance(batch_data, list):
                 fetched_additional_posts.extend(batch_data)
            elif "post_stream" in batch_data and "posts" in batch_data["post_stream"]:
                fetched_additional_posts.extend(batch_data["post_stream"]["posts"])
            elif "posts" in batch_data and isinstance(batch_data["posts"], list):
                 fetched_additional_posts.extend(batch_data["posts"])
            else:
                print(f"Warning: Unexpected JSON structure for post batch in topic {topic_id}. Data: {str(batch_data)[:200]}...")

        except requests.exceptions.RequestException as e:
            print(f"Failed to fetch post batch for topic {topic_id} (IDs: {batch_ids}): {e}")
        except json.JSONDecodeError:
            print(f"Failed to decode JSON for post batch in topic {topic_id}. Response: {batch_response.text[:200]}...")

    if fetched_additional_posts:
        print(f"Successfully fetched {len(fetched_additional_posts)} additional posts for topic {topic_id}.")
        existing_posts_in_topic_data = {post['id']: post for post in topic_data["post_stream"]["posts"]}
        for post in fetched_additional_posts:
            if post['id'] not in existing_posts_in_topic_data:
                topic_data["post_stream"]["posts"].append(post)
                existing_posts_in_topic_data[post['id']] = post

        post_id_to_post_map = {post['id']: post for post in topic_data["post_stream"]["posts"]}

        sorted_posts = []
        for post_id_val in all_post_ids_in_stream: # Renamed post_id to post_id_val to avoid conflict
            if post_id_val in post_id_to_post_map:
                sorted_posts.append(post_id_to_post_map[post_id_val])

        topic_data["post_stream"]["posts"] = sorted_posts
        print(f"Topic {topic_id}: Final post count in JSON: {len(topic_data['post_stream']['posts'])}")

    return topic_data


def save_topic_json(topic_id, json_data, output_dir):
    """Saves the topic JSON data to a file."""
    os.makedirs(output_dir, exist_ok=True)
    filepath = os.path.join(output_dir, f"topic_{topic_id}.json")
    try:
        with open(filepath, "w", encoding="utf-8") as f:
            json.dump(json_data, f, indent=2, ensure_ascii=False)
        # print(f"Successfully saved topic {topic_id} to {filepath}") # Reduced verbosity
    except IOError as e:
        print(f"Error saving topic {topic_id} to {filepath}: {e}")


def main():
    """Main function to orchestrate the downloading process."""
    print("Script started.")
    cookies = parse_cookie_string(RAW_COOKIE_STRING)
    if not cookies and DISCOURSE_BASE_URL != "https://meta.discourse.org/":
        print("Warning: Running without cookies. This may fail for private forums or specific content.")

    topic_ids = get_topic_ids(
        DISCOURSE_BASE_URL,
        CATEGORY_SLUG,
        CATEGORY_ID,
        START_DATE,
        END_DATE,
        cookies
    )

    if not topic_ids:
        print("No topic IDs found for the given criteria. Exiting.")
        return

    total_topics = len(topic_ids)
    success_downloads = 0
    failed_topic_ids = []

    print(f"\nStarting download of {total_topics} topics...\n")

    for i, topic_id in enumerate(topic_ids, 1):
        print(f"--- [{i}/{total_topics}] Processing topic ID: {topic_id} ---")
        topic_json_data = get_full_topic_json(DISCOURSE_BASE_URL, topic_id, cookies)
        if topic_json_data:
            save_topic_json(topic_id, topic_json_data, OUTPUT_DIR)
            success_downloads += 1
        else:
            print(f"Failed to get complete data for topic {topic_id}.")
            failed_topic_ids.append(topic_id)
        # print(f"--- Finished processing topic ID: {topic_id} ---\n") # Reduced verbosity

    print("\n========= SUMMARY =========")
    print(f"Total topics identified: {total_topics}")
    print(f"Successfully downloaded full data for: {success_downloads} topics")
    print(f"Failed to download/process: {len(failed_topic_ids)} topics")
    if failed_topic_ids:
        print("Failed topic IDs:", failed_topic_ids)
    print(f"Downloaded files are in: {os.path.abspath(OUTPUT_DIR)}")
    print("Script finished.")

if __name__ == "__main__":
    main()
# Out:
# Script started.
# Fetching topic IDs from category between 2025-01-01 00:00:00+00:00 and 2025-04-15 23:59:59.999999+00:00...
# Fetched page 0, 30 topics on page. Total unique topics found so far: 3. Continuing...
# Fetched page 1, 30 topics on page. Total unique topics found so far: 6. Continuing...
# Fetched page 2, 30 topics on page. Total unique topics found so far: 26. Continuing...
# Fetched page 3, 30 topics on page. Total unique topics found so far: 54. Continuing...
# Fetched page 4, 30 topics on page. Total unique topics found so far: 84. Continuing...
# Fetched page 5, 30 topics on page. Total unique topics found so far: 114. Continuing...
# Fetched page 6, 30 topics on page. Total unique topics found so far: 118. Continuing...
# Page 7 did not yield any new unique topics. Consecutive stale pages: 1.
# Fetched page 7, 30 topics on page. Total unique topics found so far: 118. Continuing...
# Page 8 did not yield any new unique topics. Consecutive stale pages: 2.
# Fetched page 8, 30 topics on page. Total unique topics found so far: 118. Continuing...
# Page 9 did not yield any new unique topics. Consecutive stale pages: 3.
# Fetched page 9, 30 topics on page. Total unique topics found so far: 118. Continuing...
# Page 10 did not yield any new unique topics. Consecutive stale pages: 4.
# Fetched page 10, 30 topics on page. Total unique topics found so far: 118. Continuing...
# Page 11 did not yield any new unique topics. Consecutive stale pages: 5.
# No new unique topics found for 5 consecutive pages. Assuming end of relevant category listing.
# Total unique topics found in timeframe: 118
#
# Starting download of 118 topics...
#
# --- [1/118] Processing topic ID: 168449 ---
# Fetching initial data for topic 168449 from https://discourse.onlinedegree.iitm.ac.in/t/168449.json
# Topic 168449: Total posts in stream: 80, Initially loaded: 20, Missing: 60
# Fetching batch of 50 posts for topic 168449 (IDs: 600326...601333)
# Fetching batch of 10 posts for topic 168449 (IDs: 601465...603368)
# Successfully fetched 60 additional posts for topic 168449.
# Topic 168449: Final post count in JSON: 80
# --- [2/118] Processing topic ID: 172546 ---
# Fetching initial data for topic 172546 from https://discourse.onlinedegree.iitm.ac.in/t/172546.json
# Topic 172546: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 172546 already loaded in initial fetch.
# --- [3/118] Processing topic ID: 171525 ---
# Fetching initial data for topic 171525 from https://discourse.onlinedegree.iitm.ac.in/t/171525.json
# Topic 171525: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 171525 already loaded in initial fetch.
# --- [4/118] Processing topic ID: 164869 ---
# Fetching initial data for topic 164869 from https://discourse.onlinedegree.iitm.ac.in/t/164869.json
# Topic 164869: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 164869 already loaded in initial fetch.
# --- [5/118] Processing topic ID: 168458 ---
# Fetching initial data for topic 168458 from https://discourse.onlinedegree.iitm.ac.in/t/168458.json
# Topic 168458: Total posts in stream: 8, Initially loaded: 8, Missing: 0
# All posts for topic 168458 already loaded in initial fetch.
# --- [6/118] Processing topic ID: 165396 ---
# Fetching initial data for topic 165396 from https://discourse.onlinedegree.iitm.ac.in/t/165396.json
# Topic 165396: Total posts in stream: 24, Initially loaded: 20, Missing: 4
# Fetching batch of 4 posts for topic 165396 (IDs: 587860...588270)
# Successfully fetched 4 additional posts for topic 165396.
# Topic 165396: Final post count in JSON: 24
# --- [7/118] Processing topic ID: 171541 ---
# Fetching initial data for topic 171541 from https://discourse.onlinedegree.iitm.ac.in/t/171541.json
# Topic 171541: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 171541 already loaded in initial fetch.
# --- [8/118] Processing topic ID: 168987 ---
# Fetching initial data for topic 168987 from https://discourse.onlinedegree.iitm.ac.in/t/168987.json
# Topic 168987: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 168987 already loaded in initial fetch.
# --- [9/118] Processing topic ID: 168476 ---
# Fetching initial data for topic 168476 from https://discourse.onlinedegree.iitm.ac.in/t/168476.json
# Topic 168476: Total posts in stream: 17, Initially loaded: 17, Missing: 0
# All posts for topic 168476 already loaded in initial fetch.
# --- [10/118] Processing topic ID: 168482 ---
# Fetching initial data for topic 168482 from https://discourse.onlinedegree.iitm.ac.in/t/168482.json
# Topic 168482: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 168482 already loaded in initial fetch.
# --- [11/118] Processing topic ID: 165922 ---
# Fetching initial data for topic 165922 from https://discourse.onlinedegree.iitm.ac.in/t/165922.json
# Topic 165922: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 165922 already loaded in initial fetch.
# --- [12/118] Processing topic ID: 165416 ---
# Fetching initial data for topic 165416 from https://discourse.onlinedegree.iitm.ac.in/t/165416.json
# Topic 165416: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 165416 already loaded in initial fetch.
# --- [13/118] Processing topic ID: 171054 ---
# Fetching initial data for topic 171054 from https://discourse.onlinedegree.iitm.ac.in/t/171054.json
# Topic 171054: Total posts in stream: 6, Initially loaded: 6, Missing: 0
# All posts for topic 171054 already loaded in initial fetch.
# --- [14/118] Processing topic ID: 167471 ---
# Fetching initial data for topic 167471 from https://discourse.onlinedegree.iitm.ac.in/t/167471.json
# Topic 167471: Total posts in stream: 7, Initially loaded: 7, Missing: 0
# All posts for topic 167471 already loaded in initial fetch.
# --- [15/118] Processing topic ID: 163381 ---
# Fetching initial data for topic 163381 from https://discourse.onlinedegree.iitm.ac.in/t/163381.json
# Topic 163381: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 163381 already loaded in initial fetch.
# --- [16/118] Processing topic ID: 165433 ---
# Fetching initial data for topic 165433 from https://discourse.onlinedegree.iitm.ac.in/t/165433.json
# Topic 165433: Total posts in stream: 7, Initially loaded: 7, Missing: 0
# All posts for topic 165433 already loaded in initial fetch.
# --- [17/118] Processing topic ID: 168506 ---
# Fetching initial data for topic 168506 from https://discourse.onlinedegree.iitm.ac.in/t/168506.json
# Topic 168506: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 168506 already loaded in initial fetch.
# --- [18/118] Processing topic ID: 168515 ---
# Fetching initial data for topic 168515 from https://discourse.onlinedegree.iitm.ac.in/t/168515.json
# Topic 168515: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 168515 already loaded in initial fetch.
# --- [19/118] Processing topic ID: 169029 ---
# Fetching initial data for topic 169029 from https://discourse.onlinedegree.iitm.ac.in/t/169029.json
# Topic 169029: Total posts in stream: 690, Initially loaded: 20, Missing: 670
# Fetching batch of 50 posts for topic 169029 (IDs: 603039...608789)
# Fetching batch of 50 posts for topic 169029 (IDs: 608793...611788)
# Fetching batch of 50 posts for topic 169029 (IDs: 611811...613082)
# Fetching batch of 50 posts for topic 169029 (IDs: 613084...613750)
# Fetching batch of 50 posts for topic 169029 (IDs: 613756...613964)
# Fetching batch of 50 posts for topic 169029 (IDs: 613965...615143)
# Fetching batch of 50 posts for topic 169029 (IDs: 615145...616227)
# Fetching batch of 50 posts for topic 169029 (IDs: 616240...616964)
# Fetching batch of 50 posts for topic 169029 (IDs: 616965...618961)
# Fetching batch of 50 posts for topic 169029 (IDs: 618975...619572)
# Fetching batch of 50 posts for topic 169029 (IDs: 619574...620216)
# Fetching batch of 50 posts for topic 169029 (IDs: 620218...620476)
# Fetching batch of 50 posts for topic 169029 (IDs: 620479...621151)
# Fetching batch of 20 posts for topic 169029 (IDs: 621171...622891)
# Successfully fetched 670 additional posts for topic 169029.
# Topic 169029: Final post count in JSON: 690
# --- [20/118] Processing topic ID: 165959 ---
# Fetching initial data for topic 165959 from https://discourse.onlinedegree.iitm.ac.in/t/165959.json
# Topic 165959: Total posts in stream: 370, Initially loaded: 20, Missing: 350
# Fetching batch of 50 posts for topic 165959 (IDs: 590495...591193)
# Fetching batch of 50 posts for topic 165959 (IDs: 591194...591838)
# Fetching batch of 50 posts for topic 165959 (IDs: 591840...592271)
# Fetching batch of 50 posts for topic 165959 (IDs: 592280...592511)
# Fetching batch of 50 posts for topic 165959 (IDs: 592515...592917)
# Fetching batch of 50 posts for topic 165959 (IDs: 592924...593125)
# Fetching batch of 50 posts for topic 165959 (IDs: 593130...598870)
# Successfully fetched 350 additional posts for topic 165959.
# Topic 165959: Final post count in JSON: 370
# --- [21/118] Processing topic ID: 168011 ---
# Fetching initial data for topic 168011 from https://discourse.onlinedegree.iitm.ac.in/t/168011.json
# Topic 168011: Total posts in stream: 7, Initially loaded: 7, Missing: 0
# All posts for topic 168011 already loaded in initial fetch.
# --- [22/118] Processing topic ID: 168017 ---
# Fetching initial data for topic 168017 from https://discourse.onlinedegree.iitm.ac.in/t/168017.json
# Topic 168017: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 168017 already loaded in initial fetch.
# --- [23/118] Processing topic ID: 169045 ---
# Fetching initial data for topic 169045 from https://discourse.onlinedegree.iitm.ac.in/t/169045.json
# Topic 169045: Total posts in stream: 6, Initially loaded: 6, Missing: 0
# All posts for topic 169045 already loaded in initial fetch.
# --- [24/118] Processing topic ID: 168537 ---
# Fetching initial data for topic 168537 from https://discourse.onlinedegree.iitm.ac.in/t/168537.json
# Topic 168537: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 168537 already loaded in initial fetch.
# --- [25/118] Processing topic ID: 166498 ---
# Fetching initial data for topic 166498 from https://discourse.onlinedegree.iitm.ac.in/t/166498.json
# Topic 166498: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 166498 already loaded in initial fetch.
# --- [26/118] Processing topic ID: 164460 ---
# Fetching initial data for topic 164460 from https://discourse.onlinedegree.iitm.ac.in/t/164460.json
# Topic 164460: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 164460 already loaded in initial fetch.
# --- [27/118] Processing topic ID: 164462 ---
# Fetching initial data for topic 164462 from https://discourse.onlinedegree.iitm.ac.in/t/164462.json
# Topic 164462: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 164462 already loaded in initial fetch.
# --- [28/118] Processing topic ID: 168567 ---
# Fetching initial data for topic 168567 from https://discourse.onlinedegree.iitm.ac.in/t/168567.json
# Topic 168567: Total posts in stream: 15, Initially loaded: 15, Missing: 0
# All posts for topic 168567 already loaded in initial fetch.
# --- [29/118] Processing topic ID: 168057 ---
# Fetching initial data for topic 168057 from https://discourse.onlinedegree.iitm.ac.in/t/168057.json
# Topic 168057: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 168057 already loaded in initial fetch.
# --- [30/118] Processing topic ID: 162425 ---
# Fetching initial data for topic 162425 from https://discourse.onlinedegree.iitm.ac.in/t/162425.json
# Topic 162425: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 162425 already loaded in initial fetch.
# --- [31/118] Processing topic ID: 171141 ---
# Fetching initial data for topic 171141 from https://discourse.onlinedegree.iitm.ac.in/t/171141.json
# Topic 171141: Total posts in stream: 467, Initially loaded: 20, Missing: 447
# Fetching batch of 50 posts for topic 171141 (IDs: 612352...612523)
# Fetching batch of 50 posts for topic 171141 (IDs: 612538...613141)
# Fetching batch of 50 posts for topic 171141 (IDs: 613213...614261)
# Fetching batch of 50 posts for topic 171141 (IDs: 614266...614787)
# Fetching batch of 50 posts for topic 171141 (IDs: 614790...615124)
# Fetching batch of 50 posts for topic 171141 (IDs: 615131...616128)
# Fetching batch of 50 posts for topic 171141 (IDs: 616129...616347)
# Fetching batch of 50 posts for topic 171141 (IDs: 616354...617017)
# Fetching batch of 47 posts for topic 171141 (IDs: 617039...621699)
# Successfully fetched 447 additional posts for topic 171141.
# Topic 171141: Final post count in JSON: 467
# --- [32/118] Processing topic ID: 170131 ---
# Fetching initial data for topic 170131 from https://discourse.onlinedegree.iitm.ac.in/t/170131.json
# Topic 170131: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 170131 already loaded in initial fetch.
# --- [33/118] Processing topic ID: 171668 ---
# Fetching initial data for topic 171668 from https://discourse.onlinedegree.iitm.ac.in/t/171668.json
# Topic 171668: Total posts in stream: 13, Initially loaded: 13, Missing: 0
# All posts for topic 171668 already loaded in initial fetch.
# --- [34/118] Processing topic ID: 171672 ---
# Fetching initial data for topic 171672 from https://discourse.onlinedegree.iitm.ac.in/t/171672.json
# Topic 171672: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 171672 already loaded in initial fetch.
# --- [35/118] Processing topic ID: 167072 ---
# Fetching initial data for topic 167072 from https://discourse.onlinedegree.iitm.ac.in/t/167072.json
# Topic 167072: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 167072 already loaded in initial fetch.
# --- [36/118] Processing topic ID: 172707 ---
# Fetching initial data for topic 172707 from https://discourse.onlinedegree.iitm.ac.in/t/172707.json
# Topic 172707: Total posts in stream: 16, Initially loaded: 16, Missing: 0
# All posts for topic 172707 already loaded in initial fetch.
# --- [37/118] Processing topic ID: 170147 ---
# Fetching initial data for topic 170147 from https://discourse.onlinedegree.iitm.ac.in/t/170147.json
# Topic 170147: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 170147 already loaded in initial fetch.
# --- [38/118] Processing topic ID: 166576 ---
# Fetching initial data for topic 166576 from https://discourse.onlinedegree.iitm.ac.in/t/166576.json
# Topic 166576: Total posts in stream: 103, Initially loaded: 20, Missing: 83
# Fetching batch of 50 posts for topic 166576 (IDs: 595979...597737)
# Fetching batch of 33 posts for topic 166576 (IDs: 597752...605775)
# Successfully fetched 83 additional posts for topic 166576.
# Topic 166576: Final post count in JSON: 103
# --- [39/118] Processing topic ID: 166593 ---
# Fetching initial data for topic 166593 from https://discourse.onlinedegree.iitm.ac.in/t/166593.json
# Topic 166593: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 166593 already loaded in initial fetch.
# --- [40/118] Processing topic ID: 168142 ---
# Fetching initial data for topic 168142 from https://discourse.onlinedegree.iitm.ac.in/t/168142.json
# Topic 168142: Total posts in stream: 8, Initially loaded: 8, Missing: 0
# All posts for topic 168142 already loaded in initial fetch.
# --- [41/118] Processing topic ID: 168143 ---
# Fetching initial data for topic 168143 from https://discourse.onlinedegree.iitm.ac.in/t/168143.json
# Topic 168143: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 168143 already loaded in initial fetch.
# --- [42/118] Processing topic ID: 166100 ---
# Fetching initial data for topic 166100 from https://discourse.onlinedegree.iitm.ac.in/t/166100.json
# Topic 166100: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 166100 already loaded in initial fetch.
# --- [43/118] Processing topic ID: 172246 ---
# Fetching initial data for topic 172246 from https://discourse.onlinedegree.iitm.ac.in/t/172246.json
# Topic 172246: Total posts in stream: 52, Initially loaded: 20, Missing: 32
# Fetching batch of 32 posts for topic 172246 (IDs: 617503...621444)
# Successfully fetched 32 additional posts for topic 172246.
# Topic 172246: Final post count in JSON: 52
# --- [44/118] Processing topic ID: 165593 ---
# Fetching initial data for topic 165593 from https://discourse.onlinedegree.iitm.ac.in/t/165593.json
# Topic 165593: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 165593 already loaded in initial fetch.
# --- [45/118] Processing topic ID: 172254 ---
# Fetching initial data for topic 172254 from https://discourse.onlinedegree.iitm.ac.in/t/172254.json
# Topic 172254: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 172254 already loaded in initial fetch.
# --- [46/118] Processing topic ID: 166634 ---
# Fetching initial data for topic 166634 from https://discourse.onlinedegree.iitm.ac.in/t/166634.json
# Topic 166634: Total posts in stream: 8, Initially loaded: 8, Missing: 0
# All posts for topic 166634 already loaded in initial fetch.
# --- [47/118] Processing topic ID: 166647 ---
# Fetching initial data for topic 166647 from https://discourse.onlinedegree.iitm.ac.in/t/166647.json
# Topic 166647: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 166647 already loaded in initial fetch.
# --- [48/118] Processing topic ID: 164089 ---
# Fetching initial data for topic 164089 from https://discourse.onlinedegree.iitm.ac.in/t/164089.json
# Topic 164089: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 164089 already loaded in initial fetch.
# --- [49/118] Processing topic ID: 166651 ---
# Fetching initial data for topic 166651 from https://discourse.onlinedegree.iitm.ac.in/t/166651.json
# Topic 166651: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 166651 already loaded in initial fetch.
# --- [50/118] Processing topic ID: 167679 ---
# Fetching initial data for topic 167679 from https://discourse.onlinedegree.iitm.ac.in/t/167679.json
# Topic 167679: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 167679 already loaded in initial fetch.
# --- [51/118] Processing topic ID: 167172 ---
# Fetching initial data for topic 167172 from https://discourse.onlinedegree.iitm.ac.in/t/167172.json
# Topic 167172: Total posts in stream: 14, Initially loaded: 14, Missing: 0
# All posts for topic 167172 already loaded in initial fetch.
# --- [52/118] Processing topic ID: 167699 ---
# Fetching initial data for topic 167699 from https://discourse.onlinedegree.iitm.ac.in/t/167699.json
# Topic 167699: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 167699 already loaded in initial fetch.
# --- [53/118] Processing topic ID: 171798 ---
# Fetching initial data for topic 171798 from https://discourse.onlinedegree.iitm.ac.in/t/171798.json
# Topic 171798: Total posts in stream: 6, Initially loaded: 6, Missing: 0
# All posts for topic 171798 already loaded in initial fetch.
# --- [54/118] Processing topic ID: 165142 ---
# Fetching initial data for topic 165142 from https://discourse.onlinedegree.iitm.ac.in/t/165142.json
# Topic 165142: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 165142 already loaded in initial fetch.
# --- [55/118] Processing topic ID: 169247 ---
# Fetching initial data for topic 169247 from https://discourse.onlinedegree.iitm.ac.in/t/169247.json
# Topic 169247: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 169247 already loaded in initial fetch.
# --- [56/118] Processing topic ID: 166189 ---
# Fetching initial data for topic 166189 from https://discourse.onlinedegree.iitm.ac.in/t/166189.json
# Topic 166189: Total posts in stream: 21, Initially loaded: 20, Missing: 1
# Fetching batch of 1 posts for topic 166189 (IDs: 633608...633608)
# Successfully fetched 1 additional posts for topic 166189.
# Topic 166189: Final post count in JSON: 21
# --- [57/118] Processing topic ID: 172333 ---
# Fetching initial data for topic 172333 from https://discourse.onlinedegree.iitm.ac.in/t/172333.json
# Topic 172333: Total posts in stream: 10, Initially loaded: 10, Missing: 0
# All posts for topic 172333 already loaded in initial fetch.
# --- [58/118] Processing topic ID: 161071 ---
# Fetching initial data for topic 161071 from https://discourse.onlinedegree.iitm.ac.in/t/161071.json
# Topic 161071: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 161071 already loaded in initial fetch.
# --- [59/118] Processing topic ID: 161072 ---
# Fetching initial data for topic 161072 from https://discourse.onlinedegree.iitm.ac.in/t/161072.json
# Topic 161072: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 161072 already loaded in initial fetch.
# --- [60/118] Processing topic ID: 164147 ---
# Fetching initial data for topic 164147 from https://discourse.onlinedegree.iitm.ac.in/t/164147.json
# Topic 164147: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 164147 already loaded in initial fetch.
# --- [61/118] Processing topic ID: 165687 ---
# Fetching initial data for topic 165687 from https://discourse.onlinedegree.iitm.ac.in/t/165687.json
# Topic 165687: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 165687 already loaded in initial fetch.
# --- [62/118] Processing topic ID: 161083 ---
# Fetching initial data for topic 161083 from https://discourse.onlinedegree.iitm.ac.in/t/161083.json
# Topic 161083: Total posts in stream: 131, Initially loaded: 20, Missing: 111
# Fetching batch of 50 posts for topic 161083 (IDs: 579005...582427)
# Fetching batch of 50 posts for topic 161083 (IDs: 582480...588128)
# Fetching batch of 11 posts for topic 161083 (IDs: 596939...625649)
# Successfully fetched 111 additional posts for topic 161083.
# Topic 161083: Final post count in JSON: 131
# --- [63/118] Processing topic ID: 169283 ---
# Fetching initial data for topic 169283 from https://discourse.onlinedegree.iitm.ac.in/t/169283.json
# Topic 169283: Total posts in stream: 44, Initially loaded: 20, Missing: 24
# Fetching batch of 24 posts for topic 169283 (IDs: 606802...618321)
# Successfully fetched 24 additional posts for topic 169283.
# Topic 169283: Final post count in JSON: 44
# --- [64/118] Processing topic ID: 170309 ---
# Fetching initial data for topic 170309 from https://discourse.onlinedegree.iitm.ac.in/t/170309.json
# Topic 170309: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 170309 already loaded in initial fetch.
# --- [65/118] Processing topic ID: 163144 ---
# Fetching initial data for topic 163144 from https://discourse.onlinedegree.iitm.ac.in/t/163144.json
# Topic 163144: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 163144 already loaded in initial fetch.
# --- [66/118] Processing topic ID: 163147 ---
# Fetching initial data for topic 163147 from https://discourse.onlinedegree.iitm.ac.in/t/163147.json
# Topic 163147: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 163147 already loaded in initial fetch.
# --- [67/118] Processing topic ID: 169807 ---
# Fetching initial data for topic 169807 from https://discourse.onlinedegree.iitm.ac.in/t/169807.json
# Topic 169807: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 169807 already loaded in initial fetch.
# --- [68/118] Processing topic ID: 166738 ---
# Fetching initial data for topic 166738 from https://discourse.onlinedegree.iitm.ac.in/t/166738.json
# Topic 166738: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 166738 already loaded in initial fetch.
# --- [69/118] Processing topic ID: 172373 ---
# Fetching initial data for topic 172373 from https://discourse.onlinedegree.iitm.ac.in/t/172373.json
# Topic 172373: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 172373 already loaded in initial fetch.
# --- [70/118] Processing topic ID: 163158 ---
# Fetching initial data for topic 163158 from https://discourse.onlinedegree.iitm.ac.in/t/163158.json
# Topic 163158: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 163158 already loaded in initial fetch.
# --- [71/118] Processing topic ID: 161120 ---
# Fetching initial data for topic 161120 from https://discourse.onlinedegree.iitm.ac.in/t/161120.json
# Topic 161120: Total posts in stream: 170, Initially loaded: 20, Missing: 150
# Fetching batch of 50 posts for topic 161120 (IDs: 579678...584251)
# Fetching batch of 50 posts for topic 161120 (IDs: 584252...588164)
# Fetching batch of 50 posts for topic 161120 (IDs: 588227...591242)
# Successfully fetched 150 additional posts for topic 161120.
# Topic 161120: Final post count in JSON: 170
# --- [72/118] Processing topic ID: 164205 ---
# Fetching initial data for topic 164205 from https://discourse.onlinedegree.iitm.ac.in/t/164205.json
# Topic 164205: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 164205 already loaded in initial fetch.
# --- [73/118] Processing topic ID: 168303 ---
# Fetching initial data for topic 168303 from https://discourse.onlinedegree.iitm.ac.in/t/168303.json
# Topic 168303: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 168303 already loaded in initial fetch.
# --- [74/118] Processing topic ID: 165746 ---
# Fetching initial data for topic 165746 from https://discourse.onlinedegree.iitm.ac.in/t/165746.json
# Topic 165746: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 165746 already loaded in initial fetch.
# --- [75/118] Processing topic ID: 168310 ---
# Fetching initial data for topic 168310 from https://discourse.onlinedegree.iitm.ac.in/t/168310.json
# Topic 168310: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 168310 already loaded in initial fetch.
# --- [76/118] Processing topic ID: 164214 ---
# Fetching initial data for topic 164214 from https://discourse.onlinedegree.iitm.ac.in/t/164214.json
# Topic 164214: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 164214 already loaded in initial fetch.
# --- [77/118] Processing topic ID: 168825 ---
# Fetching initial data for topic 168825 from https://discourse.onlinedegree.iitm.ac.in/t/168825.json
# Topic 168825: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 168825 already loaded in initial fetch.
# --- [78/118] Processing topic ID: 168832 ---
# Fetching initial data for topic 168832 from https://discourse.onlinedegree.iitm.ac.in/t/168832.json
# Topic 168832: Total posts in stream: 113, Initially loaded: 20, Missing: 93
# Fetching batch of 50 posts for topic 168832 (IDs: 602096...602962)
# Fetching batch of 43 posts for topic 168832 (IDs: 602966...605776)
# Successfully fetched 93 additional posts for topic 168832.
# Topic 168832: Final post count in JSON: 113
# --- [79/118] Processing topic ID: 164737 ---
# Fetching initial data for topic 164737 from https://discourse.onlinedegree.iitm.ac.in/t/164737.json
# Topic 164737: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 164737 already loaded in initial fetch.
# --- [80/118] Processing topic ID: 169352 ---
# Fetching initial data for topic 169352 from https://discourse.onlinedegree.iitm.ac.in/t/169352.json
# Topic 169352: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 169352 already loaded in initial fetch.
# --- [81/118] Processing topic ID: 163224 ---
# Fetching initial data for topic 163224 from https://discourse.onlinedegree.iitm.ac.in/t/163224.json
# Topic 163224: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 163224 already loaded in initial fetch.
# --- [82/118] Processing topic ID: 169369 ---
# Fetching initial data for topic 169369 from https://discourse.onlinedegree.iitm.ac.in/t/169369.json
# Topic 169369: Total posts in stream: 28, Initially loaded: 20, Missing: 8
# Fetching batch of 8 posts for topic 169369 (IDs: 604921...605766)
# Successfully fetched 8 additional posts for topic 169369.
# Topic 169369: Final post count in JSON: 28
# --- [83/118] Processing topic ID: 171422 ---
# Fetching initial data for topic 171422 from https://discourse.onlinedegree.iitm.ac.in/t/171422.json
# Topic 171422: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 171422 already loaded in initial fetch.
# --- [84/118] Processing topic ID: 166303 ---
# Fetching initial data for topic 166303 from https://discourse.onlinedegree.iitm.ac.in/t/166303.json
# Topic 166303: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 166303 already loaded in initial fetch.
# --- [85/118] Processing topic ID: 169888 ---
# Fetching initial data for topic 169888 from https://discourse.onlinedegree.iitm.ac.in/t/169888.json
# Topic 169888: Total posts in stream: 27, Initially loaded: 20, Missing: 7
# Fetching batch of 7 posts for topic 169888 (IDs: 611762...618110)
# Successfully fetched 7 additional posts for topic 169888.
# Topic 169888: Final post count in JSON: 27
# --- [86/118] Processing topic ID: 166816 ---
# Fetching initial data for topic 166816 from https://discourse.onlinedegree.iitm.ac.in/t/166816.json
# Topic 166816: Total posts in stream: 72, Initially loaded: 20, Missing: 52
# Fetching batch of 50 posts for topic 166816 (IDs: 595921...597361)
# Fetching batch of 2 posts for topic 166816 (IDs: 597622...597620)
# Successfully fetched 52 additional posts for topic 166816.
# Topic 166816: Final post count in JSON: 72
# --- [87/118] Processing topic ID: 171428 ---
# Fetching initial data for topic 171428 from https://discourse.onlinedegree.iitm.ac.in/t/171428.json
# Topic 171428: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 171428 already loaded in initial fetch.
# --- [88/118] Processing topic ID: 163241 ---
# Fetching initial data for topic 163241 from https://discourse.onlinedegree.iitm.ac.in/t/163241.json
# Topic 163241: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 163241 already loaded in initial fetch.
# --- [89/118] Processing topic ID: 170413 ---
# Fetching initial data for topic 170413 from https://discourse.onlinedegree.iitm.ac.in/t/170413.json
# Topic 170413: Total posts in stream: 6, Initially loaded: 6, Missing: 0
# All posts for topic 170413 already loaded in initial fetch.
# --- [90/118] Processing topic ID: 163247 ---
# Fetching initial data for topic 163247 from https://discourse.onlinedegree.iitm.ac.in/t/163247.json
# Topic 163247: Total posts in stream: 149, Initially loaded: 20, Missing: 129
# Fetching batch of 50 posts for topic 163247 (IDs: 584257...590530)
# Fetching batch of 50 posts for topic 163247 (IDs: 590614...591066)
# Fetching batch of 29 posts for topic 163247 (IDs: 590399...634356)
# Successfully fetched 129 additional posts for topic 163247.
# Topic 163247: Final post count in JSON: 149
# --- [91/118] Processing topic ID: 167344 ---
# Fetching initial data for topic 167344 from https://discourse.onlinedegree.iitm.ac.in/t/167344.json
# Topic 167344: Total posts in stream: 13, Initially loaded: 13, Missing: 0
# All posts for topic 167344 already loaded in initial fetch.
# --- [92/118] Processing topic ID: 169393 ---
# Fetching initial data for topic 169393 from https://discourse.onlinedegree.iitm.ac.in/t/169393.json
# Topic 169393: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 169393 already loaded in initial fetch.
# --- [93/118] Processing topic ID: 164277 ---
# Fetching initial data for topic 164277 from https://discourse.onlinedegree.iitm.ac.in/t/164277.json
# Topic 164277: Total posts in stream: 614, Initially loaded: 20, Missing: 594
# Fetching batch of 50 posts for topic 164277 (IDs: 586802...591879)
# Fetching batch of 50 posts for topic 164277 (IDs: 592061...593968)
# Fetching batch of 50 posts for topic 164277 (IDs: 593971...594250)
# Fetching batch of 50 posts for topic 164277 (IDs: 594252...594654)
# Fetching batch of 50 posts for topic 164277 (IDs: 594657...594978)
# Fetching batch of 50 posts for topic 164277 (IDs: 594979...595151)
# Fetching batch of 50 posts for topic 164277 (IDs: 595152...595366)
# Fetching batch of 50 posts for topic 164277 (IDs: 595369...595514)
# Fetching batch of 50 posts for topic 164277 (IDs: 595517...595833)
# Fetching batch of 50 posts for topic 164277 (IDs: 595845...596074)
# Fetching batch of 50 posts for topic 164277 (IDs: 596075...596182)
# Fetching batch of 44 posts for topic 164277 (IDs: 596183...615829)
# Successfully fetched 594 additional posts for topic 164277.
# Topic 164277: Final post count in JSON: 614
# --- [94/118] Processing topic ID: 163765 ---
# Fetching initial data for topic 163765 from https://discourse.onlinedegree.iitm.ac.in/t/163765.json
# Topic 163765: Total posts in stream: 6, Initially loaded: 6, Missing: 0
# All posts for topic 163765 already loaded in initial fetch.
# --- [95/118] Processing topic ID: 172471 ---
# Fetching initial data for topic 172471 from https://discourse.onlinedegree.iitm.ac.in/t/172471.json
# Topic 172471: Total posts in stream: 4, Initially loaded: 4, Missing: 0
# All posts for topic 172471 already loaded in initial fetch.
# --- [96/118] Processing topic ID: 161214 ---
# Fetching initial data for topic 161214 from https://discourse.onlinedegree.iitm.ac.in/t/161214.json
# Topic 161214: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 161214 already loaded in initial fetch.
# --- [97/118] Processing topic ID: 168384 ---
# Fetching initial data for topic 168384 from https://discourse.onlinedegree.iitm.ac.in/t/168384.json
# Topic 168384: Total posts in stream: 11, Initially loaded: 11, Missing: 0
# All posts for topic 168384 already loaded in initial fetch.
# --- [98/118] Processing topic ID: 164291 ---
# Fetching initial data for topic 164291 from https://discourse.onlinedegree.iitm.ac.in/t/164291.json
# Topic 164291: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 164291 already loaded in initial fetch.
# --- [99/118] Processing topic ID: 168901 ---
# Fetching initial data for topic 168901 from https://discourse.onlinedegree.iitm.ac.in/t/168901.json
# Topic 168901: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 168901 already loaded in initial fetch.
# --- [100/118] Processing topic ID: 167878 ---
# Fetching initial data for topic 167878 from https://discourse.onlinedegree.iitm.ac.in/t/167878.json
# Topic 167878: Total posts in stream: 3, Initially loaded: 3, Missing: 0
# All posts for topic 167878 already loaded in initial fetch.
# --- [101/118] Processing topic ID: 165830 ---
# Fetching initial data for topic 165830 from https://discourse.onlinedegree.iitm.ac.in/t/165830.json
# Topic 165830: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 165830 already loaded in initial fetch.
# --- [102/118] Processing topic ID: 166349 ---
# Fetching initial data for topic 166349 from https://discourse.onlinedegree.iitm.ac.in/t/166349.json
# Topic 166349: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 166349 already loaded in initial fetch.
# --- [103/118] Processing topic ID: 172497 ---
# Fetching initial data for topic 172497 from https://discourse.onlinedegree.iitm.ac.in/t/172497.json
# Topic 172497: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 172497 already loaded in initial fetch.
# --- [104/118] Processing topic ID: 171473 ---
# Fetching initial data for topic 171473 from https://discourse.onlinedegree.iitm.ac.in/t/171473.json
# Topic 171473: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 171473 already loaded in initial fetch.
# --- [105/118] Processing topic ID: 166866 ---
# Fetching initial data for topic 166866 from https://discourse.onlinedegree.iitm.ac.in/t/166866.json
# Topic 166866: Total posts in stream: 27, Initially loaded: 20, Missing: 7
# Fetching batch of 7 posts for topic 166866 (IDs: 594918...595546)
# Successfully fetched 7 additional posts for topic 166866.
# Topic 166866: Final post count in JSON: 27
# --- [106/118] Processing topic ID: 168916 ---
# Fetching initial data for topic 168916 from https://discourse.onlinedegree.iitm.ac.in/t/168916.json
# Topic 168916: Total posts in stream: 23, Initially loaded: 20, Missing: 3
# Fetching batch of 3 posts for topic 168916 (IDs: 615233...615539)
# Successfully fetched 3 additional posts for topic 168916.
# Topic 168916: Final post count in JSON: 23
# --- [107/118] Processing topic ID: 171477 ---
# Fetching initial data for topic 171477 from https://discourse.onlinedegree.iitm.ac.in/t/171477.json
# Topic 171477: Total posts in stream: 12, Initially loaded: 12, Missing: 0
# All posts for topic 171477 already loaded in initial fetch.
# --- [108/118] Processing topic ID: 166357 ---
# Fetching initial data for topic 166357 from https://discourse.onlinedegree.iitm.ac.in/t/166357.json
# Topic 166357: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 166357 already loaded in initial fetch.
# --- [109/118] Processing topic ID: 171485 ---
# Fetching initial data for topic 171485 from https://discourse.onlinedegree.iitm.ac.in/t/171485.json
# Topic 171485: Total posts in stream: 9, Initially loaded: 9, Missing: 0
# All posts for topic 171485 already loaded in initial fetch.
# --- [110/118] Processing topic ID: 171999 ---
# Fetching initial data for topic 171999 from https://discourse.onlinedegree.iitm.ac.in/t/171999.json
# Topic 171999: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 171999 already loaded in initial fetch.
# --- [111/118] Processing topic ID: 166891 ---
# Fetching initial data for topic 166891 from https://discourse.onlinedegree.iitm.ac.in/t/166891.json
# Topic 166891: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 166891 already loaded in initial fetch.
# --- [112/118] Processing topic ID: 171500 ---
# Fetching initial data for topic 171500 from https://discourse.onlinedegree.iitm.ac.in/t/171500.json
# Topic 171500: Total posts in stream: 9, Initially loaded: 9, Missing: 0
# All posts for topic 171500 already loaded in initial fetch.
# --- [113/118] Processing topic ID: 168943 ---
# Fetching initial data for topic 168943 from https://discourse.onlinedegree.iitm.ac.in/t/168943.json
# Topic 168943: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 168943 already loaded in initial fetch.
# --- [114/118] Processing topic ID: 169456 ---
# Fetching initial data for topic 169456 from https://discourse.onlinedegree.iitm.ac.in/t/169456.json
# Topic 169456: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 169456 already loaded in initial fetch.
# --- [115/118] Processing topic ID: 167410 ---
# Fetching initial data for topic 167410 from https://discourse.onlinedegree.iitm.ac.in/t/167410.json
# Topic 167410: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 167410 already loaded in initial fetch.
# --- [116/118] Processing topic ID: 172021 ---
# Fetching initial data for topic 172021 from https://discourse.onlinedegree.iitm.ac.in/t/172021.json
# Topic 172021: Total posts in stream: 2, Initially loaded: 2, Missing: 0
# All posts for topic 172021 already loaded in initial fetch.
# --- [117/118] Processing topic ID: 167415 ---
# Fetching initial data for topic 167415 from https://discourse.onlinedegree.iitm.ac.in/t/167415.json
# Topic 167415: Total posts in stream: 5, Initially loaded: 5, Missing: 0
# All posts for topic 167415 already loaded in initial fetch.
# --- [118/118] Processing topic ID: 171515 ---
# Fetching initial data for topic 171515 from https://discourse.onlinedegree.iitm.ac.in/t/171515.json
# Topic 171515: Total posts in stream: 1, Initially loaded: 1, Missing: 0
# All posts for topic 171515 already loaded in initial fetch.
#
# ========= SUMMARY =========
# Total topics identified: 118
# Successfully downloaded full data for: 118 topics
# Failed to download/process: 0 topics
# Downloaded files are in: /content/discourse_json
# Script finished.

# %%
import shutil
shutil.make_archive("discourse_json", 'zip', "discourse_json")
# Out:
# '/content/discourse_json.zip'

# %%
from google.colab import files
files.download("discourse_json.zip")
